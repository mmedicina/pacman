# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
scores = pd.read_csv('./scores.csv')

# %%
scores
# Out:
#       scores
# 0     -441.0
# 1     -421.0
# 2     -451.0
# 3     -457.0
# 4     -444.0
# ...      ...
# 7995  -430.0
# 7996  -167.0
# 7997  -339.0
# 7998    81.0
# 7999  -203.0
#
# [8000 rows x 1 columns]

# %%
games = np.arange(1, len(scores)+1, 1)

# %%
scores['media_movel'] = scores['scores'].rolling(10).mean()

# %%
scores['num_jogos']=games

# %%
scores
# Out:
#       scores  media_movel  num_jogos
# 0     -441.0          NaN          1
# 1     -421.0          NaN          2
# 2     -451.0          NaN          3
# 3     -457.0          NaN          4
# 4     -444.0          NaN          5
# ...      ...          ...        ...
# 7995  -430.0       -111.5       7996
# 7996  -167.0       -125.0       7997
# 7997  -339.0       -115.0       7998
# 7998    81.0       -222.6       7999
# 7999  -203.0       -225.7       8000
#
# [8000 rows x 3 columns]

# %%
import numpy as np
sns.set()
fig, ax = plt.subplots()
# the size of A4 paper
fig.set_size_inches(10,6)
sns.despine()
plt.plot(games,list(scores['scores']))
sns.lineplot(x = 'num_jogos', 
             y = 'media_movel', 
             data = scores, 
             label = 'Media Movel') 
plt.title('Parametros: learning_rate = , epsilon=, discount=')  
plt.legend()
plt.savefig('./',dpi=100)
